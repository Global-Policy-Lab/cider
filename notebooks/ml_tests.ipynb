# %%
import sys
sys.path.insert(0,'..')
from cider.ml import *

config_file = '../configs/config_conner.yml'

# %%
datastore = DataStore(config_file)
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/home/connermanuel/hadoop/spark-3.2.0/jars/slf4j-log4j12-1.7.30.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/home/connermanuel/hadoop/hadoop-3.3.0/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# 2021-11-18 09:57:44,265 WARN util.Utils: Your hostname, Hamish resolves to a loopback address: 127.0.1.1; using 172.25.6.121 instead (on interface eth0)
# 2021-11-18 09:57:44,266 WARN util.Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# ...

# %%
learner = Learner(datastore)
# Out:
# FEATURES: file:///mnt/d/College/f2021/URAP/cider/outputs/featurizer/datasets/features.csv
# Number of observations with features: 668 (668 unique)
# Number of observations with labels: 50 (50 unique)
# Number of matched observations: 31 (31 unique)
# outfname: file:///mnt/d/College/f2021/URAP/cider/outputs//merged.csv
# outfolder: file:///mnt/d/College/f2021/URAP/cider/outputs//merged
# Trying to write csv...
# Wrote csv!
# WARNING: The training data has fewer than 100 examples, which will likely result in unreliable results and a model with poor predictive performance.
# WARNING: 9.87% of features have data for less than 10% of users.

# %%
scores = learner.tuned_model(model_name='lasso')
oos_predictions = learner.oos_predictions(model_name='lasso', kind='tuned')
pop_predictions = learner.population_predictions(model_name='lasso', kind='tuned')

# %%
learner.scatter_plot(model_name='lasso', kind='tuned')

# %%
learner.feature_importances_plot(model_name='lasso', kind='tuned')

# %%
learner.targeting_table(model_name='lasso', kind='tuned')
# Out:
#   Proportion of Population Targeted  Pearson  Spearman   AUC Accuracy  \
# 0                               10%     0.33      0.31  0.62      82%
# 1                               20%     0.33      0.31  0.62      76%
# 2                               30%     0.33      0.31  0.62      65%
# 3                               40%     0.33      0.31  0.62      57%
# 4                               50%     0.33      0.31  0.62      52%
# 5                               60%     0.33      0.31  0.62      63%
# 6                               70%     0.33      0.31  0.62      74%
# 7                               80%     0.33      0.31  0.62      76%
# 8                               90%     0.33      0.31  0.62      85%
#
#   Precision Recall
# 0       10%    10%
# 1       40%    40%
# 2       43%    43%
# 3       47%    47%
# 4       52%    52%
# 5       69%    69%
# 6       81%    81%
# 7       85%    85%
# 8       92%    92%
