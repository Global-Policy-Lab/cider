# %%
import sys
sys.path.insert(0,'..')
from satellite import *

config_file = '../configs/config.yml'

# %%
datastore = DataStore(config_file)

# %%
satellite = Satellite(datastore=datastore)
# Out:
# Loading antennas...
# ...

# %%
satellite.aggregate_scores(geo='cantons')
# Out:
# ../satellite.py:152: RuntimeWarning: invalid value encountered in double_scalars
#   score = (score * pop).sum() / pop.sum()
