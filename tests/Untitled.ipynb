# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../outputs/featurizer/datasets/features.csv')

# %%
data.isna().mean()
# Out:
# name                                             0.000
# cdr_reporting__number_of_records                 0.000
# cdr_active_days__allweek__allday__callandtext    0.000
# cdr_active_days__allweek__day__callandtext       0.000
# cdr_active_days__allweek__night__callandtext     0.000
#                                                  ...
# mobilemoney_outgoing_p2p_balance_after_mean      0.303
# mobilemoney_outgoing_p2p_balance_after_min       0.303
# mobilemoney_outgoing_p2p_balance_after_max       0.303
# mobilemoney_outgoing_p2p_txns                    0.303
# mobilemoney_outgoing_p2p_contacts                0.303
# Length: 1030, dtype: float64

# %%
data.values
# Out:
# array([['dsBHAdXrrk', 184, 58, ..., 218.6359, 8.0, 8.0],
#        ['JGPCbfDGes', 209, 59, ..., 173.27129, 6.0, 6.0],
#        ['dYwshzRseD', 205, 59, ..., 200.48862, 4.0, 4.0],
#        ...,
#        ['uXZrufHOmE', 204, 54, ..., 185.58728, 4.0, 4.0],
#        ['dJSvXqUVSY', 200, 56, ..., nan, nan, nan],
#        ['YosNCLWrFL', 200, 57, ..., 183.40103, 7.0, 7.0]], dtype=object)

# %%
pd.DataFrame(data.values, columns=data.columns)
# Out:
#            name cdr_reporting__number_of_records  \
# 0    dsBHAdXrrk                              184
# 1    JGPCbfDGes                              209
# 2    dYwshzRseD                              205
# 3    ygMEXUQDbn                              218
# 4    YtvkGlMWwe                              212
# ..          ...                              ...
# 995  amzyXHglBx                              224
# 996  zZkqaZFAtz                              216
# 997  uXZrufHOmE                              204
# 998  dJSvXqUVSY                              200
# 999  YosNCLWrFL                              200
#
#     cdr_active_days__allweek__allday__callandtext  \
# 0                                              58
# 1                                              59
# 2                                              59
# 3                                              56
# 4                                              57
# ..                                            ...
# ...

# %%
data.values[0]
# Out:
# array(['dsBHAdXrrk', 184, 58, ..., 218.6359, 8.0, 8.0], dtype=object)

# %%
pd.DataFrame(data.values[[0]], columns=data.columns)
# Out:
#          name cdr_reporting__number_of_records  \
# 0  dsBHAdXrrk                              184
#
#   cdr_active_days__allweek__allday__callandtext  \
# 0                                            58
#
#   cdr_active_days__allweek__day__callandtext  \
# 0                                         46
#
#   cdr_active_days__allweek__night__callandtext  \
# 0                                           50
#
#   cdr_active_days__weekday__allday__callandtext  \
# 0                                            41
#
#   cdr_active_days__weekday__day__callandtext  \
# 0                                         32
#
#   cdr_active_days__weekday__night__callandtext  \
# 0                                           35
#
#   cdr_active_days__weekend__allday__callandtext  \
# 0                                            17
#
#   cdr_active_days__weekend__day__callandtext  ...  \
# 0                                         14  ...
#
# ...

# %%
data.iloc[0].values
# Out:
# array(['dsBHAdXrrk', 184, 58, ..., 218.6359, 8.0, 8.0], dtype=object)

# %%
pd.DataFrame(data.iloc[0], columns=data.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1614/1654507137.py in <module>
# ----> 1 pd.DataFrame(data.iloc[0].values, columns=data.columns)
#
# ~/envs/poetry/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     670                 )
#     671             else:
# --> 672                 mgr = ndarray_to_mgr(
#     673                     data,
#     674                     index,
#
# ~/envs/poetry/lib/python3.8/site-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# ~/envs/poetry/lib/python3.8/site-packages/pandas/core/internals/construction.py in _check_values_indices_shape_match(values, index, columns)
# ...

# %%
pd.DataFrame(data.iloc[[0]], columns=data.columns)
# Out:
#          name  cdr_reporting__number_of_records  \
# 0  dsBHAdXrrk                               184
#
#    cdr_active_days__allweek__allday__callandtext  \
# 0                                             58
#
#    cdr_active_days__allweek__day__callandtext  \
# 0                                          46
#
#    cdr_active_days__allweek__night__callandtext  \
# 0                                            50
#
#    cdr_active_days__weekday__allday__callandtext  \
# 0                                             41
#
#    cdr_active_days__weekday__day__callandtext  \
# 0                                          32
#
#    cdr_active_days__weekday__night__callandtext  \
# 0                                            35
#
#    cdr_active_days__weekend__allday__callandtext  \
# 0                                             17
#
#    cdr_active_days__weekend__day__callandtext  ...  \
# 0                                          14  ...
#
# ...
